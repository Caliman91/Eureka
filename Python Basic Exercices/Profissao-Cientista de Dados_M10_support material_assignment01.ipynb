# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"Profissao- Cientista de Dados_M10_support material.csv")
df
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %%
quantitativas = df.loc[:, ['qtd_filhos', 'idade', 'tempo_emprego', 'qt_pessoas_residencia', 'renda', 'tipo_renda']]
quantitativas
# Out:
#        qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda  \
# 0               1     36       3.575342                    3.0  3369.24
# 1               0     42       0.860274                    2.0  6096.14
# 2               2     31       8.065753                    4.0  5658.98
# 3               0     50       1.208219                    2.0  7246.69
# 4               0     52      13.873973                    2.0  4017.37
# ...           ...    ...            ...                    ...      ...
# 14995           1     37       2.046575                    3.0  1193.29
# 14996           1     30      12.079452                    3.0  2519.18
# 14997           0     40       2.161644                    2.0  1586.85
# 14998           0     47       3.295890                    2.0  6975.39
# 14999           0     50       3.049315                    2.0   993.86
#
#              tipo_renda
# 0           Assalariado
# 1            Empresário
# 2           Assalariado
# ...

# %%
sns.pairplot(quantitativas, hue = "tipo_renda")
# Out:
# C:\Users\ncali\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ncali\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ncali\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ncali\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
quantitativas_ = df.loc[:, ['qtd_filhos', 'idade', 'tempo_emprego', 'qt_pessoas_residencia', 'renda']]
quantitativas_
# Out:
#        qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda
# 0               1     36       3.575342                    3.0  3369.24
# 1               0     42       0.860274                    2.0  6096.14
# 2               2     31       8.065753                    4.0  5658.98
# 3               0     50       1.208219                    2.0  7246.69
# 4               0     52      13.873973                    2.0  4017.37
# ...           ...    ...            ...                    ...      ...
# 14995           1     37       2.046575                    3.0  1193.29
# 14996           1     30      12.079452                    3.0  2519.18
# 14997           0     40       2.161644                    2.0  1586.85
# 14998           0     47       3.295890                    2.0  6975.39
# 14999           0     50       3.049315                    2.0   993.86
#
# [15000 rows x 5 columns]

# %%
# Cria matriz de correlação
matriz_correlacao = quantitativas_.corr()


# Mostra matriz de correlação como mapa de calor
sns.heatmap(matriz_correlacao, annot=True)
quantitativas_.corr()
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.364303      -0.074250
# idade                   -0.364303  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.896488 -0.338805      -0.065748
# renda                    0.009567  0.042570       0.394235
#
#                        qt_pessoas_residencia     renda
# qtd_filhos                          0.896488  0.009567
# idade                              -0.338805  0.042570
# tempo_emprego                      -0.065748  0.394235
# qt_pessoas_residencia               1.000000  0.020977
# renda                               0.020977  1.000000

# %% [markdown]
# Podemos notar por exemplo, que a variável qt_pessoas_residencia aumenta com o aumento da variável qtd_filhos, e que os assalariados tem maior quantidade de filhos.
#
# E que a variável renda aumenta com a variável tempo de emprego, e que os que possuem mais renda são os assalariados e servidores públicos.

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
df['renda'].describe()
# Out:
# count    15000.000000
# mean      4624.632946
# std       4628.571729
# min        159.900000
# 25%       1945.740000
# 50%       3278.260000
# 75%       5642.365000
# max      89918.040000
# Name: renda, dtype: float64

# %%
 scatterplot = sns.scatterplot(x = "tempo_emprego", y = "renda", data = df)

# %%
 scatterplot = sns.scatterplot(x = "idade", y = "renda", data = df)

# %% [markdown]
# 3) Na sua aopinião, há outliers na variável renda?

# %% [markdown]
# Positivo, há outliers tanto para o conjunto de variáveis tempo_emprego / renda & idade / renda.

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
df["Logaritmo_renda"] = np.log(df["renda"])
df
# Out:
#        Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0               0  2015-01-01   8682    F             False             True
# 1               1  2015-01-01  12830    M              True             True
# 2               2  2015-01-01   2885    M              True             True
# 3               3  2015-01-01  16168    F              True            False
# 4               4  2015-01-01  12438    M             False            False
# ...           ...         ...    ...  ...               ...              ...
# 14995       14995  2016-03-01   3678    M              True             True
# 14996       14996  2016-03-01   3405    M              True             True
# 14997       14997  2016-03-01   7944    F              True             True
# 14998       14998  2016-03-01  16019    F             False             True
# 14999       14999  2016-03-01  12895    F              True             True
#
# ...

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %%
cor2 = df.loc[:, ['qtd_filhos', 'idade', 'tempo_emprego', 'qt_pessoas_residencia', 'renda', "Logaritmo_renda"]]
cor2
# Out:
#        qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia    renda  \
# 0               1     36       3.575342                    3.0  3369.24
# 1               0     42       0.860274                    2.0  6096.14
# 2               2     31       8.065753                    4.0  5658.98
# 3               0     50       1.208219                    2.0  7246.69
# 4               0     52      13.873973                    2.0  4017.37
# ...           ...    ...            ...                    ...      ...
# 14995           1     37       2.046575                    3.0  1193.29
# 14996           1     30      12.079452                    3.0  2519.18
# 14997           0     40       2.161644                    2.0  1586.85
# 14998           0     47       3.295890                    2.0  6975.39
# 14999           0     50       3.049315                    2.0   993.86
#
#        Logaritmo_renda
# 0             8.122442
# 1             8.715411
# 2             8.640999
# ...

# %%
# Cria matriz de correlação

matriz_correlacao = cor2.corr()


# Mostra matriz de correlação como mapa de calor
sns.heatmap(matriz_correlacao, annot=True)
cor2.corr()
# Out:
#                        qtd_filhos     idade  tempo_emprego  \
# qtd_filhos               1.000000 -0.364303      -0.074250
# idade                   -0.364303  1.000000       0.323934
# tempo_emprego           -0.074250  0.323934       1.000000
# qt_pessoas_residencia    0.896488 -0.338805      -0.065748
# renda                    0.009567  0.042570       0.394235
# Logaritmo_renda          0.023743  0.024712       0.379556
#
#                        qt_pessoas_residencia     renda  Logaritmo_renda
# qtd_filhos                          0.896488  0.009567         0.023743
# idade                              -0.338805  0.042570         0.024712
# tempo_emprego                      -0.065748  0.394235         0.379556
# qt_pessoas_residencia               1.000000  0.020977         0.036267
# renda                               0.020977  1.000000         0.835734
# Logaritmo_renda                     0.036267  0.835734         1.000000

# %%
scatterplot = sns.scatterplot(x = "idade", y = "Logaritmo_renda", data = df)

# %%
scatterplot = sns.scatterplot(x = "tempo_emprego", y = "Logaritmo_renda", data = df)

# %% [markdown]
# Negativo, as análises pioraram. A correlação que antes era de  0.042570 para renda x idade caiu para 0.024712 Logaritmo_renda x idade.
#
# A correlação que antes era de  0.394235 para renda x tempo_emprego caiu para 0.379556 Logaritmo_renda x tempo_emprego.
