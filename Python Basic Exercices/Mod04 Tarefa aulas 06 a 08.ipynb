# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl"
r = requests.get(url)
r.status_code
# Out:
# 200

# %%
data_json = r.json()
print(data_json["items"])
# Out:
# [{'id_pleito': 33460, 'tipo_interessado': 'Município', 'interessado': 'Três Barras do Paraná', 'cod_ibge': 4127858, 'uf': 'PR', 'num_pvl': 'PVL02.002532/2019-80', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Aquisição de terrenos, imóveis e/ou construção de instalações', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Paraná S/A', 'moeda': 'Real', 'valor': 400000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 1, 'data_status': '06/03/2020'}, {'id_pleito': 33528, 'tipo_interessado': 'Município', 'interessado': 'Canela', 'cod_ibge': 4304408, 'uf': 'RS', 'num_pvl': 'PVL02.002322/2019-91', 'status': 'Deferido', 'num_processo': '17944.102269/2019-91', 'data_protocolo': '2019-06-26T14:12:42Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'm
# ...

# %%
pd.DataFrame(data_json["items"]).head(2)
# Out:
#    id_pleito tipo_interessado            interessado  cod_ibge  uf  \
# 0      33460        Município  Três Barras do Paraná   4127858  PR
# 1      33528        Município                 Canela   4304408  RS
#
#                 num_pvl             status          num_processo  \
# 0  PVL02.002532/2019-80  Deferido (PVL-IF)                  None
# 1  PVL02.002322/2019-91           Deferido  17944.102269/2019-91
#
#          data_protocolo                tipo_operacao  \
# 0                  None  Operação contratual interna
# 1  2019-06-26T14:12:42Z  Operação contratual interna
#
#                                           finalidade  \
# 0  Aquisição de terrenos, imóveis e/ou construção...
# 1                                     Infraestrutura
#
#                        tipo_credor                            credor moeda  \
# 0  Instituição Financeira Nacional  Agência de Fomento do Paraná S/A  Real
# 1  Instituição Financeira Nacional           Caixa Econômica Federal  Real
#
# ...

# %%
df = pd.DataFrame(data_json["items"])
df_ = df[df["uf"] == "RJ"]
display(df_.head(2))
# Out:
#     id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 6       31378        Município      Petrópolis   3303906  RJ
# 68      62993        Município  Paraíba do Sul   3303708  RJ
#
#                  num_pvl             status          num_processo  \
# 6   PVL02.000583/2019-77           Deferido  17944.101202/2019-39
# 68  PVL02.000025/2023-98  Deferido (PVL-IF)                  None
#
#           data_protocolo                tipo_operacao      finalidade  \
# 6   2019-04-11T19:29:03Z  Operação contratual interna           PNAFM
# 68                  None  Operação contratual interna  Infraestrutura
#
#                         tipo_credor                   credor moeda      valor  \
# 6   Instituição Financeira Nacional  Caixa Econômica Federal  Real  9200000.0
# 68  Instituição Financeira Nacional      Banco do Brasil S/A  Real  3900000.0
#
#     pvl_assoc_divida  pvl_contradado_credor data_status
# 6                  1                      1  23/04/2019
# ...

# %%
df_.status.unique()
# Out:
# array(['Deferido', 'Deferido (PVL-IF)',
#        'Em retificação pelo interessado (PVL-IF)', 'Em análise (PVL-IF)',
#        'Arquivado', 'Regularizado', 'Arquivado por decurso de prazo',
#        'Encaminhado à PGFN com manifestação técnica favorável',
#        'Arquivado a pedido (PVL-IF)', 'Arquivado a pedido'], dtype=object)

# %%
df_["status"].value_counts()
# Out:
# status
# Deferido                                                 25
# Arquivado                                                12
# Encaminhado à PGFN com manifestação técnica favorável    12
# Deferido (PVL-IF)                                         6
# Regularizado                                              4
# Arquivado por decurso de prazo                            4
# Em retificação pelo interessado (PVL-IF)                  1
# Em análise (PVL-IF)                                       1
# Arquivado a pedido (PVL-IF)                               1
# Arquivado a pedido                                        1
# Name: count, dtype: int64

# %%
df["data_status"] = pd.to_datetime(df["data_status"], format = "%d/%m/%Y")
df["data_status"].dt.year.value_counts()
# Out:
# data_status
# 2008    485
# 2019    385
# 2007    310
# 2010    293
# 2023    273
# 2022    266
# 2021    255
# 2014    251
# 2006    243
# 2018    239
# 2009    223
# 2012    218
# 2011    212
# 2013    210
# 2020    209
# 2017    175
# 2016    173
# 2004    165
# 2015    152
# 2002    121
# 2003     91
# 2005     51
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=SP&tipo_interessado=Estado'
re = requests.get(url)

# %%
re.status_code
# Out:
# 200

# %%
data_json = re.json()
print(data_json)
# Out:
# {'items': [{'id_pleito': 26940, 'tipo_interessado': 'Estado', 'interessado': 'São Paulo', 'cod_ibge': 35, 'uf': 'SP', 'num_pvl': 'PVL02.002362/2017-71', 'status': 'Deferido', 'num_processo': '17944.103065/2017-13', 'data_protocolo': '2017-12-20T15:41:35Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Renegociação de dívidas', 'tipo_credor': 'União', 'credor': 'União', 'moeda': 'Real', 'valor': 223539966235.09, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '21/12/2017'}, {'id_pleito': 11263, 'tipo_interessado': 'Estado', 'interessado': 'São Paulo', 'cod_ibge': 35, 'uf': 'SP', 'num_pvl': None, 'status': 'Arquivado', 'num_processo': '17944.001396/2011-16', 'data_protocolo': '2011-09-21T03:00:00Z', 'tipo_operacao': 'Operação contratual externa (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Internacional', 'credor': 'Banco Interamericano de Desenvolvimento', 'moeda': 'Dólar dos EUA', 'valor': 748633000
# ...

# %%
pd.DataFrame(data_json["items"]).head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf               num_pvl  \
# 0      26940           Estado   São Paulo        35  SP  PVL02.002362/2017-71
# 1      11263           Estado   São Paulo        35  SP                  None
#
#       status          num_processo        data_protocolo  \
# 0   Deferido  17944.103065/2017-13  2017-12-20T15:41:35Z
# 1  Arquivado  17944.001396/2011-16  2011-09-21T03:00:00Z
#
#                                        tipo_operacao               finalidade  \
# 0                        Operação contratual interna  Renegociação de dívidas
# 1  Operação contratual externa (com garantia da U...           Infraestrutura
#
#                             tipo_credor  \
# 0                                 União
# 1  Instituição Financeira Internacional
#
#                                     credor          moeda         valor  \
# 0                                    União           Real  2.235400e+11
# ...

# %%
df_sp = pd.DataFrame(data_json["items"])
df_sp_uf_interessado = df_sp[["uf", "interessado"]]
df_sp_uf_interessado
# Out:
#     uf interessado
# 0   SP   São Paulo
# 1   SP   São Paulo
# 2   SP   São Paulo
# 3   SP   São Paulo
# 4   SP   São Paulo
# ..  ..         ...
# 89  SP   São Paulo
# 90  SP   São Paulo
# 91  SP   São Paulo
# 92  SP   São Paulo
# 93  SP   São Paulo
#
# [94 rows x 2 columns]

# %%
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=MG&tipo_interessado=Estado"

re_ = requests.get(url)
re_.status_code
# Out:
# 200

# %%
data_json = re_.json()
print(data_json)
# Out:
# {'items': [{'id_pleito': 11054, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001346/2012-10', 'data_protocolo': '2012-10-29T02:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Proinveste', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 1326389531.69, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '02/01/2013'}, {'id_pleito': 10338, 'tipo_interessado': 'Estado', 'interessado': 'Minas Gerais', 'cod_ibge': 31, 'uf': 'MG', 'num_pvl': None, 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.001175/2009-23', 'data_protocolo': '2009-09-22T03:00:00Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'PEF - Prog
# ...

# %%
pd.DataFrame(data_json["items"])
df_mg = pd.DataFrame(data_json["items"])
df_mg
# Out:
#     id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 0       11054           Estado  Minas Gerais        31  MG
# 1       10338           Estado  Minas Gerais        31  MG
# 2        9197           Estado  Minas Gerais        31  MG
# 3       13695           Estado  Minas Gerais        31  MG
# 4       20458           Estado  Minas Gerais        31  MG
# 5       13587           Estado  Minas Gerais        31  MG
# 6       13672           Estado  Minas Gerais        31  MG
# 7       13447           Estado  Minas Gerais        31  MG
# 8       22380           Estado  Minas Gerais        31  MG
# 9       27063           Estado  Minas Gerais        31  MG
# 10       5582           Estado  Minas Gerais        31  MG
# 11      13595           Estado  Minas Gerais        31  MG
# 12       7002           Estado  Minas Gerais        31  MG
# 13      10265           Estado  Minas Gerais        31  MG
# 14       5967           Estado  Minas Gerais        31  MG
# ...

# %%
df_mg["status"].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    20
# Deferido                                                  7
# Arquivado a pedido                                        5
# Arquivado                                                 3
# Arquivado pela STN                                        3
# Indeferido                                                1
# Arquivado por decurso de prazo                            1
# Name: count, dtype: int64

# %%
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Munic%C3%ADpio"

r = requests.get(url)

data_json = r.json()

print(data_json["items"])
# Out:
# [{'id_pleito': 64400, 'tipo_interessado': 'Município', 'interessado': 'Morro do Chapéu', 'cod_ibge': 2921708, 'uf': 'BA', 'num_pvl': 'PVL02.000824/2023-64', 'status': 'Deferido', 'num_processo': '17944.101984/2023-92', 'data_protocolo': '2023-05-11T20:01:23Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 8000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '17/05/2023'}, {'id_pleito': 66150, 'tipo_interessado': 'Município', 'interessado': 'Eunápolis', 'cod_ibge': 2910727, 'uf': 'BA', 'num_pvl': 'PVL02.002927/2023-69', 'status': 'Em retificação pelo credor', 'num_processo': '17944.103773/2023-94', 'data_protocolo': '2023-08-28T13:27:44Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real'
# ...

# %%
pd.DataFrame(data_json["items"]).head(2)
# Out:
#    id_pleito tipo_interessado      interessado  cod_ibge  uf  \
# 0      64400        Município  Morro do Chapéu   2921708  BA
# 1      66150        Município        Eunápolis   2910727  BA
#
#                 num_pvl                      status          num_processo  \
# 0  PVL02.000824/2023-64                    Deferido  17944.101984/2023-92
# 1  PVL02.002927/2023-69  Em retificação pelo credor  17944.103773/2023-94
#
#          data_protocolo                tipo_operacao      finalidade  \
# 0  2023-05-11T20:01:23Z  Operação contratual interna  Infraestrutura
# 1  2023-08-28T13:27:44Z  Operação contratual interna  Infraestrutura
#
#                        tipo_credor                   credor moeda  \
# 0  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 1  Instituição Financeira Nacional  Caixa Econômica Federal  Real
#
#          valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    8000000.0                 0                      0  17/05/2023
# ...

# %%
df = pd.DataFrame(data_json["items"]).head(2)

# %%
df_ = df[["interessado", "status"]]
df_.value_counts()

print("O municipio da Bahia com mais Status é a cidade de Jaraguá do sul!")
# Out:
# O municipio da Bahia com mais Status é a cidade de Jaraguá do sul!

# %%
url = "https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=BA&tipo_interessado=Estado"

r = requests.get(url)
data_json = r.json()

print(data_json["items"])
# Out:
# [{'id_pleito': 18441, 'tipo_interessado': 'Estado', 'interessado': 'Bahia', 'cod_ibge': 29, 'uf': 'BA', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19407.000023/2005-92', 'data_protocolo': '2006-01-16T02:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Desenvolvimento sustentável', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Nordeste do Brasil S/A', 'moeda': 'Dólar dos EUA', 'valor': 15000000, 'pvl_assoc_divida': 1, 'pvl_contradado_credor': 0, 'data_status': '21/02/2006'}, {'id_pleito': 18583, 'tipo_interessado': 'Estado', 'interessado': 'Bahia', 'cod_ibge': 29, 'uf': 'BA', 'num_pvl': None, 'status': 'Deferido', 'num_processo': '19407.000057/2002-34', 'data_protocolo': '2002-06-17T03:00:00Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Saneamento básico', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 1303036.61, 'pvl_assoc_divida': 1, 'pvl
# ...

# %%
pd.DataFrame(data_json["items"])
df = pd.DataFrame(data_json["items"])
df.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl    status  \
# 0      18441           Estado       Bahia        29  BA    None  Deferido
# 1      18583           Estado       Bahia        29  BA    None  Deferido
#
#            num_processo        data_protocolo                tipo_operacao  \
# 0  19407.000023/2005-92  2006-01-16T02:00:00Z  Operação contratual interna
# 1  19407.000057/2002-34  2002-06-17T03:00:00Z  Operação contratual interna
#
#                     finalidade                      tipo_credor  \
# 0  Desenvolvimento sustentável  Instituição Financeira Nacional
# 1            Saneamento básico  Instituição Financeira Nacional
#
#                             credor          moeda        valor  \
# 0  Banco do Nordeste do Brasil S/A  Dólar dos EUA  15000000.00
# 1          Caixa Econômica Federal           Real   1303036.61
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 1                      0  21/02/2006
# ...

# %%
import os
df.to_csv(os.path.join(r"C:\Users\ncali\OneDrive\Documentos\EBAC\CIÊNCIA DE DADOS\CD - MODULO 5\PARTE 3", "solicitações da Bahia.csv"), index = False, sep = ";")

# %% [markdown]
# **Mudar o diretório acima para salvar o arquivo.csv em sua máquina.**
